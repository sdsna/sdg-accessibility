# %%
import geopandas as gpd
import pandas as pd
# %matplotlib inline

# %%
asia = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/asia_cities.gpkg')
africa = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/africa_cities.gpkg')
oceania = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/oceania_cities.gpkg')
europe = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/europe_cities.gpkg')
south_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/south-america_cities.gpkg')
central_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/central-america_cities.gpkg')
north_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/north-america_cities.gpkg')

# %%
asia = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/asia_cities_weightedpoi.gpkg')
africa = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/africa_cities_weightedpoi.gpkg')
oceania = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/oceania_cities_weightedpoi.gpkg')
europe = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/europe_cities_weightedpoi.gpkg')
south_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/south-america_cities_weightedpoi.gpkg')
central_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/central-america_cities_weightedpoi.gpkg')
north_america = gpd.read_file('/Users/guilhermeiablonovski/Dropbox (SDSN)/SDG Geospatial Indicators Project/sdg-accessibility/data/final_by_continent/north-america_cities_weightedpoi.gpkg')

# %%
world_cities = pd.concat([asia,africa,europe,oceania,south_america,central_america,north_america])

# %%
world_cities.plot()
# Out:
# <AxesSubplot:>

# %%
len(world_cities)
# Out:
# 5680

# %%
world_cities = world_cities.drop_duplicates('geometry')

# %%
len(world_cities)
# Out:
# 5580

# %%
world_cities.to_file('data/final_by_continent/world_cities_raw_weightedpoi.gpkg')
